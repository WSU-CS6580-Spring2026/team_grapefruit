# %% [markdown]
# # CS6580 - Sprint 1
#
# ## Team Grapefruit
#
# *Weber State University*

# %%
# Imports and global definitions

import pandas as pd
import numpy as np
import os

interim_path = "https://connorwtech.com/resources/downloads/interim/"
processed_path = "https://connorwtech.com/resources/downloads/processed/"

# %% [markdown]
# ## Question 1: Data Loading and Exploration

# %%
df_A = pd.read_csv(processed_path + "df_A.csv")
df_B = pd.read_csv(processed_path + "df_B.csv")

# %%
print("df_A shape:", df_A.shape)
display(df_A.head())
display(df_A.info())
# Out:
# df_A shape: (514, 31)
#    fips  TOT_POP_1519_C  TOT_POP_2024_C  TOT_POP_2529_C  TOT_POP_3034_C  \
# 0  1003           11600            9449           10247           10709
# 1  1015            8607            9022            7601            7186
# 2  1055            7224            6070            6022            6024
# 3  1073           44662           46405           48533           44764
# 4  1081           13185           21095           10675            8672
#
#    TOT_POP_3539_C  TOT_FEMALE_1519_C  TOT_FEMALE_2024_C  TOT_FEMALE_2529_C  \
# 0           11558               5670               4656               5064
# 1            7232               4264               4548               3890
# 2            6931               3456               3006               3057
# 3           42291              22094              24107              25309
# 4            8721               6604              10227               5245
#
#    TOT_FEMALE_3034_C  ...  H_FEMALE_1519_C  H_FEMALE_2024_C  H_FEMALE_2529_C  \
# 0               5392  ...              263              315              345
# 1               3669  ...              125              211              170
# 2               3129  ...              138              153              142
# 3              23312  ...              743             1170             1347
# 4               4443  ...              199              289              200
#
#    H_FEMALE_3034_C  H_FEMALE_3539_C  dem2010_P  birth_rate_2010_N  \
# 0              327              263   0.227007              11.89
# 1              167              109   0.333515              11.12
# 2              125               92   0.301366              11.84
# 3             1145              864   0.523792              13.51
# 4              171              140   0.394529              10.92
#
#    births_2010_N  birth_rate_2020_N  births_2020_N
# 0         2167.0              10.00         2292.0
# 1         1318.0              11.12         1262.0
# 2         1236.0              11.44         1171.0
# 3         8894.0              12.10         7929.0
# 4         1532.0              11.04         1842.0
#
# [5 rows x 31 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 514 entries, 0 to 513
# Data columns (total 31 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   fips               514 non-null    int64
#  1   TOT_POP_1519_C     514 non-null    int64
#  2   TOT_POP_2024_C     514 non-null    int64
#  3   TOT_POP_2529_C     514 non-null    int64
#  4   TOT_POP_3034_C     514 non-null    int64
#  5   TOT_POP_3539_C     514 non-null    int64
#  6   TOT_FEMALE_1519_C  514 non-null    int64
#  7   TOT_FEMALE_2024_C  514 non-null    int64
#  8   TOT_FEMALE_2529_C  514 non-null    int64
#  9   TOT_FEMALE_3034_C  514 non-null    int64
#  10  TOT_FEMALE_3539_C  514 non-null    int64
#  11  WA_FEMALE_1519_C   514 non-null    int64
#  12  WA_FEMALE_2024_C   514 non-null    int64
#  13  WA_FEMALE_2529_C   514 non-null    int64
#  14  WA_FEMALE_3034_C   514 non-null    int64
#  15  WA_FEMALE_3539_C   514 non-null    int64
#  16  BA_FEMALE_1519_C   514 non-null    int64
#  17  BA_FEMALE_2024_C   514 non-null    int64
#  18  BA_FEMALE_2529_C   514 non-null    int64
#  19  BA_FEMALE_3034_C   514 non-null    int64
#  20  BA_FEMALE_3539_C   514 non-null    int64
#  21  H_FEMALE_1519_C    514 non-null    int64
#  22  H_FEMALE_2024_C    514 non-null    int64
#  23  H_FEMALE_2529_C    514 non-null    int64
#  24  H_FEMALE_3034_C    514 non-null    int64
#  25  H_FEMALE_3539_C    514 non-null    int64
#  26  dem2010_P          514 non-null    float64
#  27  birth_rate_2010_N  514 non-null    float64
#  28  births_2010_N      514 non-null    float64
#  29  birth_rate_2020_N  514 non-null    float64
#  30  births_2020_N      514 non-null    float64
# dtypes: float64(5), int64(26)
# memory usage: 124.6 KB
# None

# %%
print("df_B shape:", df_B.shape)
display(df_B.head())
display(df_B.info())
# Out:
# df_B shape: (514, 29)
#    fips  TOT_POP_1519_C  TOT_POP_2024_C  TOT_POP_2529_C  TOT_POP_3034_C  \
# 0  1003           13865           11342           12438           13110
# 1  1015            8613            8189            7566            7268
# 2  1055            6132            5925            6483            5997
# 3  1073           42319           41675           48750           48392
# 4  1081           14437           22170           12568           11349
#
#    TOT_POP_3539_C  TOT_FEMALE_1519_C  TOT_FEMALE_2024_C  TOT_FEMALE_2529_C  \
# 0           13976               6893               5624               6231
# 1            6977               4273               4082               3836
# 2            6169               2979               2919               3294
# 3           44968              21093              21528              25304
# 4           11139               7228              10564               6283
#
#    TOT_FEMALE_3034_C  ...  BA_FEMALE_3034_C  BA_FEMALE_3539_C  \
# 0               6697  ...               714               696
# 1               3677  ...               854               797
# 2               3152  ...               595               561
# 3              25316  ...             11556             10986
# 4               5782  ...              1535              1451
#
#    H_FEMALE_1519_C  H_FEMALE_2024_C  H_FEMALE_2529_C  H_FEMALE_3034_C  \
# 0              512              388              330              440
# 1              260              176              134              188
# 2              222              174              173              186
# 3             1358             1192             1183             1236
# 4              417              385              284              368
#
#    H_FEMALE_3539_C  dem2020_P  birth_rate_2020_N  births_2020_N
# 0              447   0.224090              10.00         2292.0
# 1              164   0.298452              11.12         1262.0
# 2              151   0.242352              11.44         1171.0
# 3             1142   0.557585              12.10         7929.0
# 4              280   0.389928              11.04         1842.0
#
# [5 rows x 29 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 514 entries, 0 to 513
# Data columns (total 29 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   fips               514 non-null    int64
#  1   TOT_POP_1519_C     514 non-null    int64
#  2   TOT_POP_2024_C     514 non-null    int64
#  3   TOT_POP_2529_C     514 non-null    int64
#  4   TOT_POP_3034_C     514 non-null    int64
#  5   TOT_POP_3539_C     514 non-null    int64
#  6   TOT_FEMALE_1519_C  514 non-null    int64
#  7   TOT_FEMALE_2024_C  514 non-null    int64
#  8   TOT_FEMALE_2529_C  514 non-null    int64
#  9   TOT_FEMALE_3034_C  514 non-null    int64
#  10  TOT_FEMALE_3539_C  514 non-null    int64
#  11  WA_FEMALE_1519_C   514 non-null    int64
#  12  WA_FEMALE_2024_C   514 non-null    int64
#  13  WA_FEMALE_2529_C   514 non-null    int64
#  14  WA_FEMALE_3034_C   514 non-null    int64
#  15  WA_FEMALE_3539_C   514 non-null    int64
#  16  BA_FEMALE_1519_C   514 non-null    int64
#  17  BA_FEMALE_2024_C   514 non-null    int64
#  18  BA_FEMALE_2529_C   514 non-null    int64
#  19  BA_FEMALE_3034_C   514 non-null    int64
#  20  BA_FEMALE_3539_C   514 non-null    int64
#  21  H_FEMALE_1519_C    514 non-null    int64
#  22  H_FEMALE_2024_C    514 non-null    int64
#  23  H_FEMALE_2529_C    514 non-null    int64
#  24  H_FEMALE_3034_C    514 non-null    int64
#  25  H_FEMALE_3539_C    514 non-null    int64
#  26  dem2020_P          514 non-null    float64
#  27  birth_rate_2020_N  514 non-null    float64
#  28  births_2020_N      514 non-null    float64
# dtypes: float64(3), int64(26)
# memory usage: 116.6 KB
# None
